# %% [markdown]
# ## Lab 3.4: csvs, functions, numpy, and distributions
#
# Run the cell below to load the required packages and set up plotting in the notebook!

# %%
import numpy as np
import scipy.stats as stats
import csv
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ### Sales data
#
# For this lab we will be using a truncated version of some sales data that we will be looking at further down the line in more detail.
#
# The csv has about 200 rows of data and 4 columns. The relative path to the csv ```sales_info.csv``` is provided below. If you copied files over and moved them around, this might be different for you and you will have to figure out the correct relative path to enter.

# %%
sales_csv_path = '../../assets/datasets/sales_info.csv'

# %% [markdown]
# #### 1. Loading the data
#
# Set up an empty list called ```rows```.
#
# Using the pattern for loading csvs we learned earlier, add all of the rows in the csv file to the rows list.
#
# For your reference, the pattern is:
# ```python
# with open(my_csv_path, 'r') as f:
#     reader = csv.reader(f)
#     ...
# ```
#
# Beyond this, adding the rows in the csv file to the ```rows``` variable is up to you.

# %%
df = pd.read_csv(sales_csv_path)

print df.head()
print df.columns.values
# Out:
#    volume_sold  2015_margin  2015_q1_sales  2016_q1_sales
# 0    18.420760    93.802281      337166.53      337804.05
# 1     4.776510    21.082425       22351.86       21736.63
# 2    16.602401    93.612494      277764.46      306942.27
# 3     4.296111    16.824704       16805.11        9307.75
# 4     8.156023    35.011457       54411.42       58939.90
# ['volume_sold' '2015_margin' '2015_q1_sales' '2016_q1_sales']

# %% [markdown]
# ##### 2. Separate header and data
#
# The header of the csv is contained in the first index of the ```rows``` variable, as it is the first row in the csv file.
#
# Use python indexing to create two new variables: ```header``` which contains the 4 column names, and ```data``` which contains the list of lists, each sub-list representing a row from the csv.
#
# Lastly, print ```header``` to see the names of the columns.

# %%
header = list(df.columns.values)
data = [list(row) for row in df.as_matrix()]
print header
data
# Out:
# ['volume_sold', '2015_margin', '2015_q1_sales', '2016_q1_sales']
# [[18.420760486100001,
#   93.802281458300001,
#   337166.53000000003,
#   337804.04999999999],
#  [4.7765099191800005,
#   21.082424687700001,
#   22351.860000000001,
#   21736.630000000001],
#  [16.602400607699998,
#   93.612494302399995,
#   277764.46000000002,
#   306942.27000000002],
#  [4.2961114982600002, 16.824703832800001, 16805.110000000001, 9307.75],
#  [8.1560232820100005,
#   35.011457003400004,
#   54411.419999999998,
#   58939.900000000001],
#  [5.0051224251799997, 31.877437232800002, 255939.81, 332979.03000000003],
#  [14.60675, 76.518973021600004, 319020.69, 302592.88],
#  [4.4564664948499999,
#   19.337345360800001,
#   45340.330000000002,
#   55315.230000000003],
#  [5.0475296509699996, 26.142470349, 57849.230000000003, 42398.57],
#  [5.38807023767, 22.4270237673, 51031.040000000001, 56241.57],
#  [9.3473486347399994,
#   41.892132963999998,
#   68657.910000000003,
#   3536.1399999999999],
#  [10.930397727300001,
#   66.403049242400002,
#   4151.9300000000003,
#   137416.92999999999],
#  [6.2702086049499997, 47.869324206899996, 121837.56, 158476.54999999999],
#  [12.3959191176, 86.760150401100006, 146725.31, 125731.50999999999],
#  [4.5577118961399998,
#   22.948176257600004,
#   119287.75999999999,
#   21834.490000000002],
#  [8.4439324116699996, 37.407112135200002, 17232.450000000001, 19203.82],
#  [5.15196394076, 20.6980424984, 21340.779999999999, 25302.919999999998],
#  [6.5370686456399998,
#   22.888218923899998,
#   16617.849999999999,
#   18650.959999999999],
#  [8.5004452359800009,
#   27.507729296500003,
#   21711.709999999999,
#   14626.290000000001],
#  [3.9315432692300005,
#   21.811658653800002,
#   28128.950000000001,
#   46323.730000000003],
#  [6.1636891385800006,
#   25.428520599299997,
#   21803.200000000001,
#   535381.85999999999],
#  [4.9044471153800009,
#   19.568317307699999,
#   12517.290000000001,
#   812011.78000000003],
#  [7.4024127108700002, 26.9353354257, 53988.919999999998, 206247.57000000001],
#  [47.503269230800001, 235.730677515, 555707.40000000002, 6402.7799999999997],
#  [55.739180093800002, 268.86960024500002, 1082136.01, 100765.67],
#  [11.8407803201, 56.4333884407, 192089.45999999999, 20098.610000000001],
#  [7.0022935779799997,
#   26.440917431199999,
#   5574.9899999999998,
#   68230.360000000001],
#  [8.7531420670600006, 45.2938472174, 80241.270000000004, 596063.0],
#  [3.1477413032800001,
#   15.594551690299999,
#   27043.540000000001,
#   87471.429999999993],
#  [7.196778794400001, 27.2886517761, 61977.540000000001, 431990.70000000001],
#  [76.203691813800006, 367.22565329099996, 977772.62, 136717.57000000001],
#  [10.804337108599999, 42.031199200500005, 41905.18, 30008.810000000001],
#  [10.705327050999999, 45.891477272700001, 87839.449999999997, 19420.34],
#  [51.800686274499995,
#   255.15323529400001,
#   445058.32000000001,
#   274752.59999999998],
#  [5.8827787173099999, 27.512271367199997, 127495.17999999999, 10315.35],
#  [6.6864064516099999,
#   26.103096774200001,
#   23874.669999999998,
#   45252.419999999998],
#  [5.8333548804099999,
#   23.741603102800003,
#   21535.869999999999,
#   433832.28000000003],
#  [45.556095638500004,
#   218.00834997400003,
#   276096.17999999999,
#   74215.429999999993],
#  [5.17260575296, 21.548781725900003, 8506.7900000000009, 78137.289999999994],
#  [10.118018017999999,
#   46.700708708699999,
#   49163.010000000002,
#   83915.720000000001],
#  [51.675537420399998,
#   233.53318869400002,
#   434110.57000000001,
#   372240.71999999997],
#  [2.7946314972799997,
#   11.996117699200001,
#   73789.380000000005,
#   148021.89999999999],
#  [7.6116977985300007, 38.809973315500002, 88006.839999999997, 31184.18],
#  [15.697651273900002,
#   105.03520700600001,
#   117958.96000000001,
#   33324.360000000001],
#  [50.275893215600007,
#   225.05513849900001,
#   407738.78999999998,
#   32079.130000000001]]

# %% [markdown]
# #### 3. Create a dictionary with the data
#
# Use loops or list comprehensions to create a dictionary called ```sales_data```, where the keys of the dictionary are the column names, and the values of the dictionary are lists of the data points of the column corresponding to that column name.

# %%
sales_data = {}

def funct(hdr, dt):
    for i in hdr:
        #print head
        for j in dt:
            for t in j:
                if j.index(t) == hdr.index(i):
                    if i not in sales_data:
                        sales_data[i] = [t]
                    else:
                        sales_data[i].append(t)
    return sales_data

funct(header, data)
# Out:
# {'2015_margin': [93.802281458300001,
#   21.082424687700001,
#   93.612494302399995,
#   16.824703832800001,
#   7.3909879863699999,
#   6.4336058859200005,
#   13.799977448499998,
#   6.4470395525400006,
#   8.0179447775100012,
#   6.2553554255999995,
#   9.6974218190499997,
#   7.7726835123199995,
#   8.7519203072499998,
#   6.7928893794500009,
#   7.6824943820199998,
#   4.3854551161300002,
#   3.6067102040800005,
#   8.4536470588199997,
#   5.2148818597600002,
#   8.4005614973300009,
#   6.8413632781699993,
#   12.5099672623,
#   9.0148700564999995,
#   7.2003642479599996,
#   5.7780967741900007,
#   4.9412939297099996,
#   6.0004507042299995,
#   11.9971174753,
#   10.6377691184,
#   8.5642280982900001,
#   8.6226864147100013,
#   4.8311471321699999,
#   10.2701848998,
#   12.581694560699999,
#   16.059970674500001,
#   11.8677385892,
#   10.294501133800001,
#   4.1760655737699999,
#   9.3618987341800004,
#   11.091708542699999,
#   5.3244966442999999,
#   6.6309043927600007,
#   8.5839240506300012,
#   5.5310610932500008,
#   6.1391231028699993,
#   8.4773760330600005,
#   8.4439324116699996,
#   5.15196394076,
#   6.5370686456399998,
#   8.5004452359800009,
#   3.9315432692300005,
#   6.1636891385800006,
#   4.9044471153800009,
#   7.4024127108700002,
#   47.503269230800001,
#   55.739180093800002,
#   11.8407803201,
#   7.0022935779799997,
#   8.7531420670600006,
#   3.1477413032800001,
#   7.196778794400001,
#   76.203691813800006,
#   10.804337108599999,
#   10.705327050999999,
#   51.800686274499995,
#   5.8827787173099999,
#   6.6864064516099999,
#   5.8333548804099999,
#   45.556095638500004,
#   5.17260575296,
#   10.118018017999999,
#   51.675537420399998,
#   2.7946314972799997,
#   7.6116977985300007,
#   15.697651273900002,
#   50.275893215600007]}

# %% [markdown]
# **3.A** Print out the first 10 items of the 'volume_sold' column.

# %%
sales_data['volume_sold'][:10]
# Out:
# [18.420760486100001,
#  4.7765099191800005,
#  16.602400607699998,
#  4.2961114982600002,
#  8.1560232820100005,
#  5.0051224251799997,
#  14.60675,
#  4.4564664948499999,
#  5.0475296509699996,
#  5.38807023767]

# %% [markdown]
# #### 4. Convert data from string to float
#
# As you can see, the data is still in string format (which is how it is read in from the csv). For each key:value pair in our ```sales_data``` dictionary, convert the values (column data) from string values to float values.

# %%
#sales_data.items()[1][1]

for key, val in sales_data.items():
    #print val
    for values in val:
        values = float(values)
print type(values)
# Out:
# <type 'float'>

# %% [markdown]
# #### 5. Write function to print summary statistics
#
# Now write a function to print out summary statistics for the data.
#
# Your function should:
#
# - Accept two arguments: the column name and the data associated with that column
# - Print out information, clearly labeling each item when you print it:
#     1. Print out the column name
#     2. Print the mean of the data using ```np.mean()```
#     3. Print out the median of the data using ```np.median()```
#     4. Print out the mode of the **rounded data** using ```stats.mode()```
#     5. Print out the variance of the data using ```np.var()```
#     6. Print out the standard deviation of the data using ```np.std()```
#
# Remember that you will need to convert the numeric data from these function to strings by wrapping them in the ```str()``` function.

# %%
def statsss(column_name, data):
    x = data[column_name]
    #y = data[column_name]
    rounder = []
    #print sales_data[column_name]
    print "Mean: ", str(np.mean(x))
    print "Median: ",str(np.median(x))
    for value in data[column_name]:
        rounder.append(round(value))
    #print rounder
    print "Mode: ",str(stats.mode(rounder))
    print "Variance: ",str(np.var(x))
    print "Std Deviation: ",str(np.std(x))
statsss('volume_sold', sales_data)
# Out:
# Mean:  10.018684079
# Median:  8.16634551564
# Mode:  ModeResult(mode=array([ 8.]), count=array([28]))
# Variance:  84.1299652005
# Std Deviation:  9.1722388325

# %% [markdown]
# **5.A** Using your function, print the summary statistics for 'volume_sold'

# %%
statsss('volume_sold', sales_data)
# Out:
# Mean:  10.018684079
# Median:  8.16634551564
# Mode:  ModeResult(mode=array([ 8.]), count=array([28]))
# Variance:  84.1299652005
# Std Deviation:  9.1722388325

# %% [markdown]
# **5.B** Using your function, print the summary statistics for '2015_margin'

# %%
statsss('2015_margin', sales_data)
# Out:
# Mean:  46.8588951379
# Median:  36.5621438181
# Mode:  ModeResult(mode=array([ 35.]), count=array([9]))
# Variance:  2016.06166296
# Std Deviation:  44.9005753077

# %% [markdown]
# **5.C** Using your function, print the summary statistics for '2015_q1_sales'

# %%
statsss('2015_q1_sales', sales_data)
# Out:
# Mean:  154631.6682
# Median:  104199.41
# Mode:  ModeResult(mode=array([ 4152.]), count=array([1]))
# Variance:  47430301462.3
# Std Deviation:  217784.989066

# %% [markdown]
# **5.D** Using your function, print the summary statistics for '2016_q1_sales'

# %%
statsss('2016_q1_sales', sales_data)
# Out:
# Mean:  154699.17875
# Median:  103207.2
# Mode:  ModeResult(mode=array([ 3536.]), count=array([1]))
# Variance:  47139411653.4
# Std Deviation:  217116.124812

# %% [markdown]
# #### 6. Plot the distributions
#
# We've provided a plotting function below called ```distribution_plotter()```. It takes two arguments, the name of the column and the data associated with that column.
#
# In individual cells, plot the distributions for each of the 4 columns. Do the data appear skewed? Symmetrical? If skewed, what would be your hypothesis for why?

# %%
def distribution_plotter(column, data):
    sns.set(rc={"figure.figsize": (10, 7)})
    sns.set_style("white")
    dist = sns.distplot(data['column'], hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    dist.set_title('Distribution of ' + column + '\n', fontsize=16)

## the function wouldnt work for me, i tried doing many things to correct
## it but to no avail. I'm unsure why my input isn't working when
## it appears to be formatted correctly (based off the previous function)

# %%
distribution_plotter('volume_sold', sales_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-e88e20a3fbc2> in <module>()
# ----> 1 distribution_plotter('volume_sold', sales_data)
#
# <ipython-input-73-54c1ac97ce77> in distribution_plotter(column, data)
#       2     sns.set(rc={"figure.figsize": (10, 7)})
#       3     sns.set_style("white")
# ----> 4     dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
#       5     #dist.set_title('Distribution of ' + column + '\n', fontsize=16)
#
# /Users/dnay/anaconda/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     190             line, = ax.plot(0, a.mean())
#     191         else:
# --> 192             line, = ax.plot(a.mean(), 0)
#     193         color = line.get_color()
#     194         line.remove()
#
# /Users/dnay/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      70         ret = ret.dtype.type(ret / rcount)
#      71     else:
# ---> 72         ret = ret / rcount
#      73
#      74     return ret
#
# TypeError: unsupported operand type(s) for /: 'dict' and 'int'
